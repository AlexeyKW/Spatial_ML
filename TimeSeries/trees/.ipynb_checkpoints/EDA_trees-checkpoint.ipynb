# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.feature_selection import RFE
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# %%
X_train = pd.read_csv('data_trees.csv', index_col=None)

# %%
X_train.head()
# Out:
#         ID   SITE SPECIES  FIRSTCEN  DEATHYEAR   HT83   HT84   HT85   HT86  \
# 0  60275.0  AREAI      LA    1983.0     1984.0   61.0 -999.0 -999.0 -999.0
# 1   6101.0  AREAI      LA    1983.0     1984.0   52.0 -999.0 -999.0 -999.0
# 2  60313.0  AREAI      LA    1983.0     1984.0   42.0 -999.0 -999.0 -999.0
# 3   5065.0  AREAI      MG    1983.0     -999.0  257.0  263.0  264.0  253.0
# 4   5066.0  AREAI      MG    1983.0     -999.0  240.0  223.0  246.0  235.0
#
#     HT87   HT88   HT89   HT90   HT91   HT92   HT93   HT94   HT95   HT96  \
# 0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 1 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 2 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 3  273.0  276.0  240.0  285.0  285.0  293.0  304.0  305.0  278.0  325.0
# 4  276.0  252.0  248.0  256.0  278.0  294.0  297.0  297.0  300.0  308.0
#
#     HT97   HT98   HT99   HT00  HGRO8384  HGRO8485  HGRO8586  HGRO8687  \
# ...

# %%
X_train['HT83'].plot(figsize=(12,6))

# %%
sns.distplot(X_train.HT83);
print( 'Kurtosis of normal distribution: {}'.format(stats.kurtosis(X_train.HT83)))
print( 'Skewness of normal distribution: {}'.format(stats.skew(X_train.HT83)))
# Out:
# E:\Miniconda3\lib\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# E:\Miniconda3\lib\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# E:\Miniconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# E:\Miniconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# Kurtosis of normal distribution: nan
# Skewness of normal distribution: nan
